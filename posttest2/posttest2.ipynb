# %% [markdown]
# # POSTTEST 2
#  #### Nama : Desti Yulianingsih
#  #### NIM : 2209106059

# %% [markdown]
# ### Import library pandas untuk membaca dataset

# %%
import pandas as pd
sb = pd.read_csv('football-league.csv')
sb
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie   None    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %% [markdown]
# ### 1. Menampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka

# %%
sb.select_dtypes('int').describe() #untuk menampilkan atribut yang bertipe angka atau integer
# Out:
#        Matches_Played  Substitution          Mins       Goals       Shots  \
# count      660.000000     660.000000   660.000000  660.000000  660.000000
# mean        22.371212       3.224242  2071.416667   11.784848   64.177273
# std          9.754658       3.839498   900.595049    5.982454   34.941622
# min          2.000000       0.000000   264.000000    2.000000    5.000000
# 25%         14.000000       0.000000  1363.500000    8.000000   37.750000
# 50%         24.000000       2.000000  2245.500000   11.000000   62.000000
# 75%         31.000000       5.000000  2822.000000   14.000000   86.000000
# max         38.000000      26.000000  4177.000000   37.000000  208.000000
#
#          OnTarget         Year
# count  660.000000   660.000000
# mean    28.365152  2018.363636
# std     16.363149     1.367700
# min      2.000000  2016.000000
# 25%     17.000000  2017.000000
# 50%     26.000000  2019.000000
# 75%     37.000000  2019.000000
# max    102.000000  2020.000000

# %% [markdown]
# ### 2. Menampilkan 10 record pertama dari dataset dengan attribute bertipe angka

# %%
sb.select_dtypes('int').head(11) #untuk menampilkan atribut yang bertipe angka dengan 10 record pertama
# Out:
#     Matches_Played  Substitution   Mins  Goals  Shots  OnTarget  Year
# 0               19             16  1849     11     48        20  2016
# 1               36              0  3129     16     88        41  2016
# 2               34              1  2940     28    120        57  2016
# 3               32              3  2842     13    117        42  2016
# 4               21             10  1745     13     50        23  2016
# 5               29              0  2634     25    162        60  2016
# 6               23              6  1967     11     69        34  2016
# 7               30              0  2694     13    105        42  2016
# 8               25              7  2354     19     78        37  2016
# 9               31              7  2904     11     64        26  2016
# 10              27              5  2480     16     85        45  2016

# %% [markdown]
# ### 3. Menampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka.

# %%
from prettytable import PrettyTable #mengimport prettytable, untuk membuat tampilan table lebih rapi

jumlah_record = sb.size
jumlah_atribut = len(sb.columns)
nama_atribut = sb.columns
jumlah_atribut = len(sb.select_dtypes('int').columns)

info = {
    "Jumlah Record" : jumlah_record,
    "Jumlah Attribute" : jumlah_atribut,
    "Nama Attribute" : nama_atribut,
    "Jumlah Attribute bertipe Angka" : jumlah_atribut
}

table = PrettyTable()
for i in info.keys():
    table.add_column(i, [])
table.add_row([info.get(i, "") for i in info.keys()])
print(table)
# Out:
# +---------------+------------------+-------------------------------------------------------------------------------+--------------------------------+
# | Jumlah Record | Jumlah Attribute |                                 Nama Attribute                                | Jumlah Attribute bertipe Angka |
# +---------------+------------------+-------------------------------------------------------------------------------+--------------------------------+
# |      9900     |        7         |     Index(['Country', 'League', 'Club', 'Player Names', 'Matches_Played',     |               7                |
# |               |                  |         'Substitution ', 'Mins', 'Goals', 'xG', 'xG Per Avg Match', 'Shots',  |                                |
# |               |                  |        'OnTarget', 'Shots Per Avg Match', 'On Target Per Avg Match', 'Year'], |                                |
# ...

# %% [markdown]
# ### 4. Menampilkan jumlah label dari semua attribute yang bernilai object

# %%
jumlah_label = sb.select_dtypes(include = ['object'])
jumlah_label.count()
# Out:
# Country         660
# League          660
# Club            660
# Player Names    660
# dtype: int64

# %% [markdown]
# ##### 5. Memvisualisasikan dataset dengan grafik histogram

# %%
import matplotlib.pyplot as plt

sb['Year'].value_counts()

fig = plt.figure(figsize=(20,15))

plt.hist(sb['Year'], bins = 15, color = 'blue', edgecolor = 'white')
plt.title('Country League')
plt.ylabel('Match Played')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ##### 6. Menampilkan korelasi dataset menggunakan heatmap.

# %%
sb.corr()
# Out:
#                          Matches_Played  Substitution       Mins     Goals  \
# Matches_Played                 1.000000      -0.080422  0.981231  0.676200
# Substitution                  -0.080422       1.000000  0.006075  0.043922
# Mins                           0.981231       0.006075  1.000000  0.686461
# Goals                          0.676200       0.043922  0.686461  1.000000
# xG                             0.695411       0.004738  0.708465  0.906220
# xG Per Avg Match              -0.163790       0.001942 -0.160581  0.379092
# Shots                          0.788192       0.001490  0.796597  0.834758
# OnTarget                       0.722838       0.007776  0.728925  0.863684
# Shots Per Avg Match           -0.005875       0.009738 -0.011351  0.409114
# On Target Per Avg Match       -0.066603       0.029030 -0.071387  0.431668
# Year                          -0.546415      -0.219274 -0.525116 -0.433296
#
# ...

# %% [markdown]
# ### HeatMap
# import library seaborn untuk memvisualisasikan HeatMap

# %%
import seaborn as sns

# %%
sns.heatmap(
    sb.corr(),
    annot=True,
    annot_kws={'size':5}
)

plt.show()

# %% [markdown]
# ### Kesimpulan
#
# Atribut yang bertipe angka memiliki jumlah record 9900 dengan jumlah atribut sebanyak 7 yaitu Matches_Played, Substitution, Mins, Goals, Shots, OnTarget dan Year.
#
# Untuk atribut yang bernilai object ada 4 yaitu Country, League, Club, Player Names dengan jumlah label 660 dari semua atribut.
#
# Berdasarkan visualisasi histogram, pada tahun 2019 adalah match played tertinggi dan tahun 2017 adalah match played terendah.
# Berdasarkan heatmap, ada korelasi kuat antara menit bermain, tembakan, dan gol. Mins (menit bermain) berkorelasi tinggi dengan Matches_Played. Goals sangat berkaitan dengan xG, Shots, dan OnTarget. Korelasi negatif dengan Year menunjukkan penurunan performa dalam beberapa tahun terakhir.
